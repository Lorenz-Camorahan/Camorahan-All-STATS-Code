# %% [markdown]
# <h1> LISTS AND TUPLES </h1>

# %% [markdown]
# <hr style="border: none; height: 4px; background-color: #210bb3ff; width: 100%;">

# %% [markdown]
# <b>Lorenz V. Camoraha</b>
# <p>Comptech Student T09</p>
# <p>12/14/2025</p>
# <hr style="border: none; height: 4px; background-color: #210bb3ff; width: 100%;">

# %% [markdown]
# <h1>CREATING A LIST</h1>
# <hr style="border: none; height: 4px; background-color: #210bb3ff; width: 100%;">

# %%
numbers = [1,2,3,4,5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
numbers[-3]
# Out:
# 3

# %%
mixed_list = [10,,20,2.5,True]
mixed_list
